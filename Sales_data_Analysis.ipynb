# %%
import pandas as pd

# %%
import pandas as pd
import glob

path = r'C:\Users\ROHIT\Desktop\python project\Sales data analysis\SalesAnalysis\Sales_Data' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

sales_data = pd.concat(li, axis=0)

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
sales_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
sales_data = sales_data.dropna()

# %%
sales_data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# # Adding monthand time columns

# %%
sales_data = sales_data[sales_data['Order Date'].str[0:2]!='Or']

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
sales_data['Month'] = pd.to_datetime(sales_data['Order Date']).dt.month
# Out:
# C:\Users\ROHIT\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address  Month
# ...

# %%
sales_data['time'] = pd.to_datetime(sales_data['Order Date']).dt.time
# Out:
# C:\Users\ROHIT\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# # Adding city columns

# %%
sales_data['city'] = sales_data['Purchase Address'].apply(lambda x:"".join( x.split(",")[1:3]))
# Out:
# C:\Users\ROHIT\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sales_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address  Month  \
# ...

# %% [markdown]
# # Question 1: What was the best month for sales? How much was earned that month?

# %%
sales_data['Revenue'] = (sales_data['Price Each'].astype('float'))*(sales_data['Quantity Ordered'].astype('int'))
# Out:
# C:\Users\ROHIT\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
best_month = sales_data.groupby('Month').sum()['Revenue'].reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
best_month
# Out:
#     Month       Revenue
# 0       1  1.822257e+06
# 1       2  2.202022e+06
# 2       3  2.807100e+06
# 3       4  3.390670e+06
# 4       5  3.152607e+06
# 5       6  2.577802e+06
# 6       7  2.647776e+06
# 7       8  2.244468e+06
# 8       9  2.097560e+06
# 9      10  3.736727e+06
# 10     11  3.199603e+06
# 11     12  4.613443e+06

# %%
sns.barplot(best_month['Month'],best_month['Revenue'])

# %% [markdown]
# # Question 2: What city sold the most product?

# %%
best_city = sales_data.groupby('city').sum()['Revenue'].reset_index()

# %%
best_city
# Out:
#                       city       Revenue
# 0         Atlanta GA 30301  2.795499e+06
# 1          Austin TX 73301  1.819582e+06
# 2          Boston MA 02215  3.661642e+06
# 3          Dallas TX 75001  2.767975e+06
# 4     Los Angeles CA 90001  5.452571e+06
# 5   New York City NY 10001  4.664317e+06
# 6        Portland ME 04101  4.497583e+05
# 7        Portland OR 97035  1.870732e+06
# 8   San Francisco CA 94016  8.262204e+06
# 9         Seattle WA 98101  2.747755e+06

# %%
plt.bar(best_city['city'],best_city['Revenue'])
plt.xticks(best_city['city'],rotation='vertical')
plt.ylabel('Revenue')
plt.xlabel('City')
plt.show()

# %% [markdown]
# # Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
best_time = sales_data.groupby('time').sum()['Revenue'].reset_index()

# %%
best_time
# Out:
#           time   Revenue
# 0     00:00:00  22488.86
# 1     00:01:00  12814.95
# 2     00:02:00  12951.64
# 3     00:03:00  18759.14
# 4     00:04:00  16960.08
# ...        ...       ...
# 1435  23:55:00  17294.89
# 1436  23:56:00  19463.40
# 1437  23:57:00  16237.62
# 1438  23:58:00  19606.93
# 1439  23:59:00  18079.08
#
# [1440 rows x 2 columns]

# %%
sns.lineplot(best_time['time'],best_time['Revenue'],markers=True)

# %% [markdown]
# # Question 4:  What product sold the most? Why do you think it sold the most?

# %%
most_sold_product = sales_data.Product.value_counts()

# %%
most_sold_product
# Out:
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: Product, dtype: int64

# %% [markdown]
# # Product generate most Revenue

# %%
top_product = sales_data.groupby('Product').sum()['Revenue'].reset_index()

# %%
top_product
# Out:
#                        Product     Revenue
# 0                 20in Monitor   454148.71
# 1       27in 4K Gaming Monitor  2435097.56
# 2             27in FHD Monitor  1132424.50
# 3       34in Ultrawide Monitor  2355558.01
# 4        AA Batteries (4-pack)   106118.40
# 5       AAA Batteries (4-pack)    92740.83
# 6     Apple Airpods Headphones  2349150.00
# 7   Bose SoundSport Headphones  1345565.43
# 8                Flatscreen TV  1445700.00
# 9                 Google Phone  3319200.00
# 10                    LG Dryer   387600.00
# 11          LG Washing Machine   399600.00
# 12    Lightning Charging Cable   347094.15
# 13          Macbook Pro Laptop  8037600.00
# 14             ThinkPad Laptop  4129958.70
# 15        USB-C Charging Cable   286501.25
# 16             Vareebadd Phone   827200.00
# 17            Wired Headphones   246478.43
# 18                      iPhone  4794300.00

# %%
plt.bar(top_product['Product'],top_product['Revenue'])
plt.xticks(top_product['Product'],rotation='vertical')
plt.xlabel('Product')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# # Question 5: What products are most often sold together?

# %%
df = sales_data[sales_data['Order ID'].duplicated(keep=False)]
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
# Out:
# C:\Users\ROHIT\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92
